# %%
import pandas as pd

# %%
data = pd.read_csv("../scripts/results_testing.csv", delimiter=',', index_col=0)

# %%
data
# Out:
#      number  position positionText  points  grid  laps    status    driverId  \
# 0        77         1            1    25.0     1    71  Finished      bottas
# 1        16         2            2    18.0     7    71  Finished     leclerc
# 2         4         3            3    16.0     3    71  Finished      norris
# 3        44         4            4    12.0     5    71  Finished    hamilton
# 4        55         5            5    10.0     8    71  Finished       sainz
# ..      ...       ...          ...     ...   ...   ...       ...         ...
# 775       6        16            R     0.0    16    50  Accident      latifi
# 776      99        17            R     0.0    14    33   Gearbox  giovinazzi
# 777      63        18            R     0.0    17    26   Gearbox     russell
# 778       7        19            R     0.0    18    25    Brakes   raikkonen
# 779       9        20            W     0.0    20     0   Illness     mazepin
#
#      driverNumber driverCode  ...  \
# ...
